# %%
#Cell Painting feature selection

# blacklist
# variance_threshold
# correlation_threshold
# drop_outliers
#

# %%
blacklist=["Nuclei_Correlation_Manders_AGP_DNA",
            "Nuclei_Correlation_Manders_AGP_ER",
            "Nuclei_Correlation_Manders_AGP_Mito",
            "Nuclei_Correlation_Manders_AGP_RNA",
            "Nuclei_Correlation_Manders_DNA_AGP",
            "Nuclei_Correlation_Manders_DNA_ER",
            "Nuclei_Correlation_Manders_DNA_Mito",
            "Nuclei_Correlation_Manders_DNA_RNA",
            "Nuclei_Correlation_Manders_ER_AGP",
            "Nuclei_Correlation_Manders_ER_DNA",
            "Nuclei_Correlation_Manders_ER_Mito",
            "Nuclei_Correlation_Manders_ER_RNA",
            "Nuclei_Correlation_Manders_Mito_AGP",
            "Nuclei_Correlation_Manders_Mito_DNA",
            "Nuclei_Correlation_Manders_Mito_ER",
            "Nuclei_Correlation_Manders_Mito_RNA",
            "Nuclei_Correlation_Manders_RNA_AGP",
            "Nuclei_Correlation_Manders_RNA_DNA",
            "Nuclei_Correlation_Manders_RNA_ER",
            "Nuclei_Correlation_Manders_RNA_Mito",
            "Nuclei_Correlation_RWC_AGP_DNA",
            "Nuclei_Correlation_RWC_AGP_ER",
            "Nuclei_Correlation_RWC_AGP_Mito",
            "Nuclei_Correlation_RWC_AGP_RNA",
            "Nuclei_Correlation_RWC_DNA_AGP",
            "Nuclei_Correlation_RWC_DNA_ER",
            "Nuclei_Correlation_RWC_DNA_Mito",
            "Nuclei_Correlation_RWC_DNA_RNA",
            "Nuclei_Correlation_RWC_ER_AGP",
            "Nuclei_Correlation_RWC_ER_DNA",
            "Nuclei_Correlation_RWC_ER_Mito",
            "Nuclei_Correlation_RWC_ER_RNA",
            "Nuclei_Correlation_RWC_Mito_AGP",
            "Nuclei_Correlation_RWC_Mito_DNA",
            "Nuclei_Correlation_RWC_Mito_ER",
            "Nuclei_Correlation_RWC_Mito_RNA",
            "Nuclei_Correlation_RWC_RNA_AGP",
            "Nuclei_Correlation_RWC_RNA_DNA",
            "Nuclei_Correlation_RWC_RNA_ER",
            "Nuclei_Correlation_RWC_RNA_Mito",
            "Nuclei_Granularity_14_AGP",
            "Nuclei_Granularity_14_DNA",
            "Nuclei_Granularity_14_ER",
            "Nuclei_Granularity_14_Mito",
            "Nuclei_Granularity_14_RNA",
            "Nuclei_Granularity_15_AGP",
            "Nuclei_Granularity_15_DNA",
            "Nuclei_Granularity_15_ER",
            "Nuclei_Granularity_15_Mito",
            "Nuclei_Granularity_15_RNA",
            "Nuclei_Granularity_16_AGP",
            "Nuclei_Granularity_16_DNA",
            "Nuclei_Granularity_16_ER",
            "Nuclei_Granularity_16_Mito",
            "Nuclei_Granularity_16_RNA"]

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#blacklist features are already removed

# %%
broad_data = pd.read_csv("./broad_data_filtered_89_CP.csv") 
broad_data
# Out:
#                                   InChICode_standardised  178_684  180_686  \
# 0      InChI=1S/C20H29NO5S/c1-13-5-3-4-6-14(2)9-18(22...      1.0      1.0
# 1      InChI=1S/C22H26N2O3/c1-25-20-9-5-18(6-10-20)4-...      1.0      1.0
# 2      InChI=1S/C10H12ClN5O3/c11-10-14-8(12)7-9(15-10...      1.0      NaN
# 3      InChI=1S/C31H39F3N4O5/c1-19-16-38(20(2)18-39)2...      1.0      NaN
# 4      InChI=1S/C36H40N4O4/c1-25-21-40(26(2)24-41)35(...      1.0      NaN
# ...                                                  ...      ...      ...
# 15267  InChI=1S/C29H42O10/c1-15-22(32)23(33)24(34)25(...      NaN      NaN
# 15268  InChI=1S/C9H11N3O4/c10-5-1-2-12-8-7(16-9(12)11...      NaN      NaN
# 15269  InChI=1S/C22H22O8/c1-25-14-5-10(6-15(26-2)20(1...      NaN      NaN
# 15270  InChI=1S/C40H71NO14/c1-15-27-40(11,48)33(44)22...      NaN      NaN
# 15271  InChI=1S/C25H34N2O3/c1-5-26(6-2)13-15-29-19-9-...      NaN      NaN
#
#        183_604  184_606  185_665  185_666  186_668  190_628  190_629  ...  \
# 0          NaN      1.0      NaN      NaN      1.0      1.0      1.0  ...
# 1          NaN      1.0      NaN      NaN      1.0      NaN      NaN  ...
# 2          1.0      1.0      NaN      NaN      NaN      1.0      NaN  ...
# 3          1.0      1.0      NaN      NaN      NaN      NaN      NaN  ...
# 4          NaN      1.0      NaN      NaN      NaN      NaN      NaN  ...
# ...        ...      ...      ...      ...      ...      ...      ...  ...
# 15267      NaN      NaN      NaN      NaN      NaN      NaN      NaN  ...
# 15268      NaN      NaN      NaN      NaN      NaN      NaN      NaN  ...
# 15269      NaN      NaN      NaN      NaN      NaN      NaN      NaN  ...
# 15270      NaN      NaN      NaN      NaN      NaN      NaN      NaN  ...
# 15271      NaN      NaN      NaN      NaN      NaN      NaN      NaN  ...
#
#        Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                             0.093061                         0.875722
# 1                             0.116051                         0.309519
# 2                            -0.294291                         0.209528
# 3                             0.039152                         0.086286
# 4                             0.040428                        -0.028181
# ...                                ...                              ...
# 15267                         2.023354                         1.082932
# 15268                        -0.896843                        -0.071896
# 15269                         0.572008                         0.493553
# 15270                         0.164852                        -0.096224
# 15271                        -0.007884                        -0.037492
#
#        Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                            0.850884                        0.839612
# 1                            0.459790                        0.401589
# 2                            0.335144                        0.237102
# 3                            0.054990                        0.058714
# 4                            0.000753                       -0.000458
# ...                               ...                             ...
# 15267                        1.488213                        1.506465
# 15268                       -0.125941                       -0.123960
# 15269                        0.644446                        0.648428
# 15270                       -0.086212                       -0.069431
# 15271                       -0.065478                       -0.036617
#
#        Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                               0.060316                          0.070135
# 1                               0.146067                          0.214701
# 2                               0.384470                          0.352664
# 3                              -0.083360                         -0.105019
# 4                              -0.188926                         -0.189808
# ...                                  ...                               ...
# 15267                           0.892884                          1.265802
# 15268                          -0.108458                         -0.124955
# 15269                           0.230773                          0.502751
# 15270                          -0.132107                         -0.102662
# 15271                          -0.033800                         -0.033718
#
#        Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                             -0.000190                         -0.108497
# 1                              0.213238                         -0.135633
# 2                              0.347354                          0.242193
# 3                             -0.094897                          0.011623
# 4                             -0.198777                         -0.048785
# ...                                 ...                               ...
# 15267                          1.439872                          1.190745
# 15268                         -0.128173                          0.260039
# 15269                          0.490447                          0.175383
# 15270                         -0.102206                          0.046411
# 15271                         -0.048740                         -0.120534
#
#        Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0
# 0                             0.085898                         0.019391
# 1                            -0.014985                        -0.017021
# 2                             0.061739                         0.146235
# 3                             0.013888                         0.011693
# 4                            -0.000681                         0.028151
# ...                                ...                              ...
# 15267                         1.632206                         1.749445
# 15268                         0.046118                         0.070403
# 15269                         0.332650                         0.245685
# 15270                         0.032759                         0.056227
# 15271                        -0.110119                        -0.140251
#
# [15272 rows x 1820 columns]

# %%
CP_features_list= broad_data.columns.to_list()[92:]
assay_list= broad_data.columns.to_list()[2:91]

# %%
CP_features_list[-1]
# Out:
# 'Nuclei_Texture_Variance_RNA_5_0'

# %%
len(CP_features_list)
# Out:
# 1728

# %%
len(assay_list)
# Out:
# 89

# %%
CP_broad_data = broad_data[CP_features_list] 
CP_broad_data["InChICode_standardised"] = broad_data["InChICode_standardised"]
CP_broad_data
# Out:
# /home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#        Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# 0               -170.397109                -13.080782
# 1                482.148438                 12.054688
# 2               2067.648438                 -3.445312
# 3                -16.257812                 16.714844
# 4                237.851562                 10.218750
# ...                     ...                       ...
# 15267          -1528.218750                 11.015625
# 15268           4005.781250                 -9.265625
# 15269            204.566406                 -7.816406
# 15270            650.210938                 -5.003906
# 15271            780.968750                  0.167969
#
#        Cells_AreaShape_Center_Y  Cells_AreaShape_Compactness  \
# 0                      7.294218                    -0.131375
# 1                    -12.906250                    -0.110156
# 2                      1.625000                     0.181624
# 3                     -3.078125                     0.000006
# 4                      3.562500                     0.055463
# ...                         ...                          ...
# 15267                 16.625000                    -0.217555
# 15268                 -8.382812                     0.229233
# 15269                -39.843750                    -0.135751
# 15270                -14.214844                     0.057152
# 15271                 -1.773438                     0.036452
#
#        Cells_AreaShape_Eccentricity  Cells_AreaShape_EulerNumber  \
# 0                         -0.072642                          0.0
# 1                         -0.063504                          0.0
# 2                          0.043458                          0.0
# 3                          0.007712                          0.0
# 4                          0.038405                          0.0
# ...                             ...                          ...
# 15267                     -0.252740                          0.0
# 15268                      0.061368                          0.0
# 15269                     -0.120535                          0.0
# 15270                      0.029558                          0.0
# 15271                      0.024478                          0.0
#
#        Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                    0.070610                    0.124399
# 1                    0.048714                    0.071378
# 2                   -0.060679                   -0.100422
# 3                    0.006149                    0.034816
# 4                   -0.009728                    0.028221
# ...                       ...                         ...
# 15267                0.159345                    0.386261
# 15268               -0.056264                   -0.102037
# 15269                0.085003                    0.152573
# 15270               -0.007969                    0.007896
# 15271               -0.008423                   -0.000317
#
#        Cells_AreaShape_MajorAxisLength  Cells_AreaShape_MaxFeretDiameter  ...  \
# 0                           -10.688622                        -13.606528  ...
# 1                             5.359095                          4.937321  ...
# 2                            48.736613                         50.425080  ...
# 3                             0.253081                          0.087672  ...
# 4                             9.327401                         10.162446  ...
# ...                                ...                               ...  ...
# 15267                       -36.140542                        -40.810164  ...
# 15268                        67.235559                         74.484606  ...
# 15269                        -3.412960                         -4.080336  ...
# 15270                        12.777864                         12.127430  ...
# 15271                        13.500671                         15.459140  ...
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_3_0  \
# 0                             0.875722                        0.850884
# 1                             0.309519                        0.459790
# 2                             0.209528                        0.335144
# 3                             0.086286                        0.054990
# 4                            -0.028181                        0.000753
# ...                                ...                             ...
# 15267                         1.082932                        1.488213
# 15268                        -0.071896                       -0.125941
# 15269                         0.493553                        0.644446
# 15270                        -0.096224                       -0.086212
# 15271                        -0.037492                       -0.065478
#
#        Nuclei_Texture_Variance_ER_5_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                            0.839612                           0.060316
# 1                            0.401589                           0.146067
# 2                            0.237102                           0.384470
# 3                            0.058714                          -0.083360
# 4                           -0.000458                          -0.188926
# ...                               ...                                ...
# 15267                        1.506465                           0.892884
# 15268                       -0.123960                          -0.108458
# 15269                        0.648428                           0.230773
# 15270                       -0.069431                          -0.132107
# 15271                       -0.036617                          -0.033800
#
#        Nuclei_Texture_Variance_Mito_3_0  Nuclei_Texture_Variance_Mito_5_0  \
# 0                              0.070135                         -0.000190
# 1                              0.214701                          0.213238
# 2                              0.352664                          0.347354
# 3                             -0.105019                         -0.094897
# 4                             -0.189808                         -0.198777
# ...                                 ...                               ...
# 15267                          1.265802                          1.439872
# 15268                         -0.124955                         -0.128173
# 15269                          0.502751                          0.490447
# 15270                         -0.102662                         -0.102206
# 15271                         -0.033718                         -0.048740
#
#        Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_3_0  \
# 0                             -0.108497                         0.085898
# 1                             -0.135633                        -0.014985
# 2                              0.242193                         0.061739
# 3                              0.011623                         0.013888
# 4                             -0.048785                        -0.000681
# ...                                 ...                              ...
# 15267                          1.190745                         1.632206
# 15268                          0.260039                         0.046118
# 15269                          0.175383                         0.332650
# 15270                          0.046411                         0.032759
# 15271                         -0.120534                        -0.110119
#
#        Nuclei_Texture_Variance_RNA_5_0  \
# 0                             0.019391
# 1                            -0.017021
# 2                             0.146235
# 3                             0.011693
# 4                             0.028151
# ...                                ...
# 15267                         1.749445
# 15268                         0.070403
# 15269                         0.245685
# 15270                         0.056227
# 15271                        -0.140251
#
#                                   InChICode_standardised
# 0      InChI=1S/C20H29NO5S/c1-13-5-3-4-6-14(2)9-18(22...
# 1      InChI=1S/C22H26N2O3/c1-25-20-9-5-18(6-10-20)4-...
# 2      InChI=1S/C10H12ClN5O3/c11-10-14-8(12)7-9(15-10...
# 3      InChI=1S/C31H39F3N4O5/c1-19-16-38(20(2)18-39)2...
# 4      InChI=1S/C36H40N4O4/c1-25-21-40(26(2)24-41)35(...
# ...                                                  ...
# 15267  InChI=1S/C29H42O10/c1-15-22(32)23(33)24(34)25(...
# 15268  InChI=1S/C9H11N3O4/c10-5-1-2-12-8-7(16-9(12)11...
# 15269  InChI=1S/C22H22O8/c1-25-14-5-10(6-15(26-2)20(1...
# 15270  InChI=1S/C40H71NO14/c1-15-27-40(11,48)33(44)22...
# 15271  InChI=1S/C25H34N2O3/c1-5-26(6-2)13-15-29-19-9-...
#
# [15272 rows x 1729 columns]

# %%
CP_broad_data.to_csv("CP_all_features_15272.csv", index=False)

# %%
from sklearn.feature_selection import VarianceThreshold
from itertools import compress

def fs_variance(df, threshold:float=0.05):
    """
    Return a list of selected variables based on the threshold.
    """

    # The list of columns in the data frame
    features = list(df.columns)
    
    # Initialize and fit the method
    vt = VarianceThreshold(threshold = threshold)
    _ = vt.fit(df)
    
    # Get which column names which pass the threshold
    feat_select = list(compress(features, vt.get_support()))
    
    return feat_select

selected_Features = fs_variance(CP_broad_data.iloc[:,:-1], threshold=0.005)
len(selected_Features)
# Out:
# 674

# %%
new_CP_broad_data= CP_broad_data[selected_Features]
new_CP_broad_data
# Out:
#        Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# 0               -170.397109                -13.080782
# 1                482.148438                 12.054688
# 2               2067.648438                 -3.445312
# 3                -16.257812                 16.714844
# 4                237.851562                 10.218750
# ...                     ...                       ...
# 15267          -1528.218750                 11.015625
# 15268           4005.781250                 -9.265625
# 15269            204.566406                 -7.816406
# 15270            650.210938                 -5.003906
# 15271            780.968750                  0.167969
#
#        Cells_AreaShape_Center_Y  Cells_AreaShape_MajorAxisLength  \
# 0                      7.294218                       -10.688622
# 1                    -12.906250                         5.359095
# 2                      1.625000                        48.736613
# 3                     -3.078125                         0.253081
# 4                      3.562500                         9.327401
# ...                         ...                              ...
# 15267                 16.625000                       -36.140542
# 15268                 -8.382812                        67.235559
# 15269                -39.843750                        -3.412960
# 15270                -14.214844                        12.777864
# 15271                 -1.773438                        13.500671
#
#        Cells_AreaShape_MaxFeretDiameter  Cells_AreaShape_MaximumRadius  \
# 0                            -13.606528                       2.436766
# 1                              4.937321                       2.575933
# 2                             50.425080                       5.133328
# 3                              0.087672                       0.188255
# 4                             10.162446                      -0.213357
# ...                                 ...                            ...
# 15267                        -40.810164                      -5.998001
# 15268                         74.484606                      10.100552
# 15269                         -4.080336                       2.166987
# 15270                         12.127430                       2.270775
# 15271                         15.459140                       2.128068
#
#        Cells_AreaShape_MeanRadius  Cells_AreaShape_MedianRadius  \
# 0                        1.140803                      0.958887
# 1                        1.147156                      1.194929
# 2                        1.406926                      1.210207
# 3                        0.114596                      0.175911
# 4                        0.028405                      0.052799
# ...                           ...                           ...
# 15267                   -1.897973                     -1.710325
# 15268                    3.199141                      2.797254
# 15269                    0.923337                      1.000704
# 15270                    0.831184                      0.869654
# 15271                    0.782620                      0.581815
#
#        Cells_AreaShape_MinFeretDiameter  Cells_AreaShape_MinorAxisLength  ...  \
# 0                              0.241876                         3.252035  ...
# 1                              3.512330                         5.087789  ...
# 2                             19.468930                        14.608241  ...
# 3                             -0.340602                        -0.568168  ...
# 4                             -0.791412                        -1.103790  ...
# ...                                 ...                              ...  ...
# 15267                        -21.273343                       -16.376487  ...
# 15268                         28.495000                        24.630145  ...
# 15269                          3.080268                         3.782605  ...
# 15270                          4.513519                         4.837297  ...
# 15271                          5.539640                         4.587185  ...
#
#        Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                             0.093061                         0.875722
# 1                             0.116051                         0.309519
# 2                            -0.294291                         0.209528
# 3                             0.039152                         0.086286
# 4                             0.040428                        -0.028181
# ...                                ...                              ...
# 15267                         2.023354                         1.082932
# 15268                        -0.896843                        -0.071896
# 15269                         0.572008                         0.493553
# 15270                         0.164852                        -0.096224
# 15271                        -0.007884                        -0.037492
#
#        Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                            0.850884                        0.839612
# 1                            0.459790                        0.401589
# 2                            0.335144                        0.237102
# 3                            0.054990                        0.058714
# 4                            0.000753                       -0.000458
# ...                               ...                             ...
# 15267                        1.488213                        1.506465
# 15268                       -0.125941                       -0.123960
# 15269                        0.644446                        0.648428
# 15270                       -0.086212                       -0.069431
# 15271                       -0.065478                       -0.036617
#
#        Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                               0.060316                          0.070135
# 1                               0.146067                          0.214701
# 2                               0.384470                          0.352664
# 3                              -0.083360                         -0.105019
# 4                              -0.188926                         -0.189808
# ...                                  ...                               ...
# 15267                           0.892884                          1.265802
# 15268                          -0.108458                         -0.124955
# 15269                           0.230773                          0.502751
# 15270                          -0.132107                         -0.102662
# 15271                          -0.033800                         -0.033718
#
#        Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                             -0.000190                         -0.108497
# 1                              0.213238                         -0.135633
# 2                              0.347354                          0.242193
# 3                             -0.094897                          0.011623
# 4                             -0.198777                         -0.048785
# ...                                 ...                               ...
# 15267                          1.439872                          1.190745
# 15268                         -0.128173                          0.260039
# 15269                          0.490447                          0.175383
# 15270                         -0.102206                          0.046411
# 15271                         -0.048740                         -0.120534
#
#        Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0
# 0                             0.085898                         0.019391
# 1                            -0.014985                        -0.017021
# 2                             0.061739                         0.146235
# 3                             0.013888                         0.011693
# 4                            -0.000681                         0.028151
# ...                                ...                              ...
# 15267                         1.632206                         1.749445
# 15268                         0.046118                         0.070403
# 15269                         0.332650                         0.245685
# 15270                         0.032759                         0.056227
# 15271                        -0.110119                        -0.140251
#
# [15272 rows x 674 columns]

# %%
def get_pairwise_correlation(population_df, method="pearson"):
    """Given a population dataframe, calculate all pairwise correlations.
    Parameters
    ----------
    population_df : pandas.core.frame.DataFrame
        Includes metadata and observation features.
    method : str, default "pearson"
        Which correlation matrix to use to test cutoff.
    Returns
    -------
    list of str
        Features to exclude from the population_df.
    """


    # Get a symmetrical correlation matrix
    data_cor_df = population_df.corr(method=method)

    # Create a copy of the dataframe to generate upper triangle of zeros
    data_cor_natri_df = data_cor_df.copy()

    # Replace upper triangle in correlation matrix with NaN
    data_cor_natri_df = data_cor_natri_df.where(
        np.tril(np.ones(data_cor_natri_df.shape), k=-1).astype(np.bool)
    )

    # Acquire pairwise correlations in a long format
    # Note that we are using the NaN upper triangle DataFrame
    pairwise_df = data_cor_natri_df.stack().reset_index()
    pairwise_df.columns = ["pair_a", "pair_b", "correlation"]

    return data_cor_df, pairwise_df

# %%
# Get correlation matrix and lower triangle of pairwise correlations in long format
data_cor_df, pairwise_df = get_pairwise_correlation(population_df=new_CP_broad_data)
# Out:
# /tmp/ipykernel_185385/3078888421.py:24: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.tril(np.ones(data_cor_natri_df.shape), k=-1).astype(np.bool)

# %%
data_cor_df
# Out:
#                                   Cells_AreaShape_Area  \
# Cells_AreaShape_Area                          1.000000
# Cells_AreaShape_Center_X                     -0.043368
# Cells_AreaShape_Center_Y                      0.008753
# Cells_AreaShape_MajorAxisLength               0.956153
# Cells_AreaShape_MaxFeretDiameter              0.960822
# ...                                                ...
# Nuclei_Texture_Variance_Mito_3_0             -0.265619
# Nuclei_Texture_Variance_Mito_5_0             -0.271592
# Nuclei_Texture_Variance_RNA_10_0              0.048784
# Nuclei_Texture_Variance_RNA_3_0              -0.083242
# Nuclei_Texture_Variance_RNA_5_0              -0.062400
#
#                                   Cells_AreaShape_Center_X  \
# Cells_AreaShape_Area                             -0.043368
# Cells_AreaShape_Center_X                          1.000000
# Cells_AreaShape_Center_Y                         -0.003357
# Cells_AreaShape_MajorAxisLength                  -0.039532
# Cells_AreaShape_MaxFeretDiameter                 -0.041218
# ...                                                    ...
# Nuclei_Texture_Variance_Mito_3_0                  0.031642
# Nuclei_Texture_Variance_Mito_5_0                  0.032580
# Nuclei_Texture_Variance_RNA_10_0                  0.021810
# Nuclei_Texture_Variance_RNA_3_0                   0.021468
# Nuclei_Texture_Variance_RNA_5_0                   0.015926
#
#                                   Cells_AreaShape_Center_Y  \
# Cells_AreaShape_Area                              0.008753
# Cells_AreaShape_Center_X                         -0.003357
# Cells_AreaShape_Center_Y                          1.000000
# Cells_AreaShape_MajorAxisLength                   0.024510
# Cells_AreaShape_MaxFeretDiameter                  0.022625
# ...                                                    ...
# Nuclei_Texture_Variance_Mito_3_0                 -0.035571
# Nuclei_Texture_Variance_Mito_5_0                 -0.034729
# Nuclei_Texture_Variance_RNA_10_0                 -0.040507
# Nuclei_Texture_Variance_RNA_3_0                  -0.070524
# Nuclei_Texture_Variance_RNA_5_0                  -0.065376
#
#                                   Cells_AreaShape_MajorAxisLength  \
# Cells_AreaShape_Area                                     0.956153
# Cells_AreaShape_Center_X                                -0.039532
# Cells_AreaShape_Center_Y                                 0.024510
# Cells_AreaShape_MajorAxisLength                          1.000000
# Cells_AreaShape_MaxFeretDiameter                         0.995370
# ...                                                           ...
# Nuclei_Texture_Variance_Mito_3_0                        -0.347048
# Nuclei_Texture_Variance_Mito_5_0                        -0.350547
# Nuclei_Texture_Variance_RNA_10_0                         0.008283
# Nuclei_Texture_Variance_RNA_3_0                         -0.133969
# Nuclei_Texture_Variance_RNA_5_0                         -0.105150
#
#                                   Cells_AreaShape_MaxFeretDiameter  \
# Cells_AreaShape_Area                                      0.960822
# Cells_AreaShape_Center_X                                 -0.041218
# Cells_AreaShape_Center_Y                                  0.022625
# Cells_AreaShape_MajorAxisLength                           0.995370
# Cells_AreaShape_MaxFeretDiameter                          1.000000
# ...                                                            ...
# Nuclei_Texture_Variance_Mito_3_0                         -0.346788
# Nuclei_Texture_Variance_Mito_5_0                         -0.350505
# Nuclei_Texture_Variance_RNA_10_0                          0.004821
# Nuclei_Texture_Variance_RNA_3_0                          -0.137467
# Nuclei_Texture_Variance_RNA_5_0                          -0.109530
#
#                                   Cells_AreaShape_MaximumRadius  \
# Cells_AreaShape_Area                                   0.953311
# Cells_AreaShape_Center_X                              -0.039049
# Cells_AreaShape_Center_Y                              -0.001166
# Cells_AreaShape_MajorAxisLength                        0.885082
# Cells_AreaShape_MaxFeretDiameter                       0.890929
# ...                                                         ...
# Nuclei_Texture_Variance_Mito_3_0                      -0.195025
# Nuclei_Texture_Variance_Mito_5_0                      -0.208527
# Nuclei_Texture_Variance_RNA_10_0                       0.101453
# Nuclei_Texture_Variance_RNA_3_0                       -0.029746
# Nuclei_Texture_Variance_RNA_5_0                       -0.012767
#
#                                   Cells_AreaShape_MeanRadius  \
# Cells_AreaShape_Area                                0.944689
# Cells_AreaShape_Center_X                           -0.028964
# Cells_AreaShape_Center_Y                            0.000002
# Cells_AreaShape_MajorAxisLength                     0.881836
# Cells_AreaShape_MaxFeretDiameter                    0.884977
# ...                                                      ...
# Nuclei_Texture_Variance_Mito_3_0                   -0.179593
# Nuclei_Texture_Variance_Mito_5_0                   -0.194220
# Nuclei_Texture_Variance_RNA_10_0                    0.114574
# Nuclei_Texture_Variance_RNA_3_0                    -0.017460
# Nuclei_Texture_Variance_RNA_5_0                     0.001104
#
#                                   Cells_AreaShape_MedianRadius  \
# Cells_AreaShape_Area                                  0.925942
# Cells_AreaShape_Center_X                             -0.025281
# Cells_AreaShape_Center_Y                              0.004639
# Cells_AreaShape_MajorAxisLength                       0.873782
# Cells_AreaShape_MaxFeretDiameter                      0.874852
# ...                                                        ...
# Nuclei_Texture_Variance_Mito_3_0                     -0.175723
# Nuclei_Texture_Variance_Mito_5_0                     -0.190437
# Nuclei_Texture_Variance_RNA_10_0                      0.119431
# Nuclei_Texture_Variance_RNA_3_0                      -0.009830
# Nuclei_Texture_Variance_RNA_5_0                       0.010133
#
#                                   Cells_AreaShape_MinFeretDiameter  \
# Cells_AreaShape_Area                                      0.964033
# Cells_AreaShape_Center_X                                 -0.056310
# Cells_AreaShape_Center_Y                                  0.002353
# Cells_AreaShape_MajorAxisLength                           0.903750
# Cells_AreaShape_MaxFeretDiameter                          0.912719
# ...                                                            ...
# Nuclei_Texture_Variance_Mito_3_0                         -0.270513
# Nuclei_Texture_Variance_Mito_5_0                         -0.280735
# Nuclei_Texture_Variance_RNA_10_0                          0.056772
# Nuclei_Texture_Variance_RNA_3_0                          -0.080779
# Nuclei_Texture_Variance_RNA_5_0                          -0.065273
#
#                                   Cells_AreaShape_MinorAxisLength  ...  \
# Cells_AreaShape_Area                                     0.951442  ...
# Cells_AreaShape_Center_X                                -0.052333  ...
# Cells_AreaShape_Center_Y                                -0.003401  ...
# Cells_AreaShape_MajorAxisLength                          0.875966  ...
# Cells_AreaShape_MaxFeretDiameter                         0.885035  ...
# ...                                                           ...  ...
# Nuclei_Texture_Variance_Mito_3_0                        -0.234709  ...
# Nuclei_Texture_Variance_Mito_5_0                        -0.246693  ...
# Nuclei_Texture_Variance_RNA_10_0                         0.069413  ...
# Nuclei_Texture_Variance_RNA_3_0                         -0.061550  ...
# Nuclei_Texture_Variance_RNA_5_0                         -0.048655  ...
#
#                                   Nuclei_Texture_Variance_DNA_5_0  \
# Cells_AreaShape_Area                                    -0.120080
# Cells_AreaShape_Center_X                                -0.014138
# Cells_AreaShape_Center_Y                                -0.031176
# Cells_AreaShape_MajorAxisLength                         -0.125303
# Cells_AreaShape_MaxFeretDiameter                        -0.138320
# ...                                                           ...
# Nuclei_Texture_Variance_Mito_3_0                         0.244250
# Nuclei_Texture_Variance_Mito_5_0                         0.242490
# Nuclei_Texture_Variance_RNA_10_0                         0.557163
# Nuclei_Texture_Variance_RNA_3_0                          0.596764
# Nuclei_Texture_Variance_RNA_5_0                          0.595819
#
#                                   Nuclei_Texture_Variance_ER_10_0  \
# Cells_AreaShape_Area                                    -0.262433
# Cells_AreaShape_Center_X                                 0.179891
# Cells_AreaShape_Center_Y                                -0.061413
# Cells_AreaShape_MajorAxisLength                         -0.292469
# Cells_AreaShape_MaxFeretDiameter                        -0.302305
# ...                                                           ...
# Nuclei_Texture_Variance_Mito_3_0                         0.325225
# Nuclei_Texture_Variance_Mito_5_0                         0.358520
# Nuclei_Texture_Variance_RNA_10_0                         0.159345
# Nuclei_Texture_Variance_RNA_3_0                          0.273227
# Nuclei_Texture_Variance_RNA_5_0                          0.261445
#
#                                   Nuclei_Texture_Variance_ER_3_0  \
# Cells_AreaShape_Area                                   -0.257752
# Cells_AreaShape_Center_X                                0.101149
# Cells_AreaShape_Center_Y                               -0.082160
# Cells_AreaShape_MajorAxisLength                        -0.296291
# Cells_AreaShape_MaxFeretDiameter                       -0.305737
# ...                                                          ...
# Nuclei_Texture_Variance_Mito_3_0                        0.401584
# Nuclei_Texture_Variance_Mito_5_0                        0.424083
# Nuclei_Texture_Variance_RNA_10_0                        0.224339
# Nuclei_Texture_Variance_RNA_3_0                         0.378256
# Nuclei_Texture_Variance_RNA_5_0                         0.362003
#
#                                   Nuclei_Texture_Variance_ER_5_0  \
# Cells_AreaShape_Area                                   -0.270393
# Cells_AreaShape_Center_X                                0.120168
# Cells_AreaShape_Center_Y                               -0.077178
# Cells_AreaShape_MajorAxisLength                        -0.306231
# Cells_AreaShape_MaxFeretDiameter                       -0.315916
# ...                                                          ...
# Nuclei_Texture_Variance_Mito_3_0                        0.390008
# Nuclei_Texture_Variance_Mito_5_0                        0.417189
# Nuclei_Texture_Variance_RNA_10_0                        0.205880
# Nuclei_Texture_Variance_RNA_3_0                         0.354852
# Nuclei_Texture_Variance_RNA_5_0                         0.340397
#
#                                   Nuclei_Texture_Variance_Mito_10_0  \
# Cells_AreaShape_Area                                      -0.246469
# Cells_AreaShape_Center_X                                   0.055286
# Cells_AreaShape_Center_Y                                  -0.019218
# Cells_AreaShape_MajorAxisLength                           -0.318657
# Cells_AreaShape_MaxFeretDiameter                          -0.319164
# ...                                                             ...
# Nuclei_Texture_Variance_Mito_3_0                           0.931422
# Nuclei_Texture_Variance_Mito_5_0                           0.953183
# Nuclei_Texture_Variance_RNA_10_0                           0.205469
# Nuclei_Texture_Variance_RNA_3_0                            0.295242
# Nuclei_Texture_Variance_RNA_5_0                            0.294346
#
#                                   Nuclei_Texture_Variance_Mito_3_0  \
# Cells_AreaShape_Area                                     -0.265619
# Cells_AreaShape_Center_X                                  0.031642
# Cells_AreaShape_Center_Y                                 -0.035571
# Cells_AreaShape_MajorAxisLength                          -0.347048
# Cells_AreaShape_MaxFeretDiameter                         -0.346788
# ...                                                            ...
# Nuclei_Texture_Variance_Mito_3_0                          1.000000
# Nuclei_Texture_Variance_Mito_5_0                          0.989692
# Nuclei_Texture_Variance_RNA_10_0                          0.219225
# Nuclei_Texture_Variance_RNA_3_0                           0.354652
# Nuclei_Texture_Variance_RNA_5_0                           0.343709
#
#                                   Nuclei_Texture_Variance_Mito_5_0  \
# Cells_AreaShape_Area                                     -0.271592
# Cells_AreaShape_Center_X                                  0.032580
# Cells_AreaShape_Center_Y                                 -0.034729
# Cells_AreaShape_MajorAxisLength                          -0.350547
# Cells_AreaShape_MaxFeretDiameter                         -0.350505
# ...                                                            ...
# Nuclei_Texture_Variance_Mito_3_0                          0.989692
# Nuclei_Texture_Variance_Mito_5_0                          1.000000
# Nuclei_Texture_Variance_RNA_10_0                          0.210897
# Nuclei_Texture_Variance_RNA_3_0                           0.348447
# Nuclei_Texture_Variance_RNA_5_0                           0.340259
#
#                                   Nuclei_Texture_Variance_RNA_10_0  \
# Cells_AreaShape_Area                                      0.048784
# Cells_AreaShape_Center_X                                  0.021810
# Cells_AreaShape_Center_Y                                 -0.040507
# Cells_AreaShape_MajorAxisLength                           0.008283
# Cells_AreaShape_MaxFeretDiameter                          0.004821
# ...                                                            ...
# Nuclei_Texture_Variance_Mito_3_0                          0.219225
# Nuclei_Texture_Variance_Mito_5_0                          0.210897
# Nuclei_Texture_Variance_RNA_10_0                          1.000000
# Nuclei_Texture_Variance_RNA_3_0                           0.911152
# Nuclei_Texture_Variance_RNA_5_0                           0.924238
#
#                                   Nuclei_Texture_Variance_RNA_3_0  \
# Cells_AreaShape_Area                                    -0.083242
# Cells_AreaShape_Center_X                                 0.021468
# Cells_AreaShape_Center_Y                                -0.070524
# Cells_AreaShape_MajorAxisLength                         -0.133969
# Cells_AreaShape_MaxFeretDiameter                        -0.137467
# ...                                                           ...
# Nuclei_Texture_Variance_Mito_3_0                         0.354652
# Nuclei_Texture_Variance_Mito_5_0                         0.348447
# Nuclei_Texture_Variance_RNA_10_0                         0.911152
# Nuclei_Texture_Variance_RNA_3_0                          1.000000
# Nuclei_Texture_Variance_RNA_5_0                          0.987692
#
#                                   Nuclei_Texture_Variance_RNA_5_0
# Cells_AreaShape_Area                                    -0.062400
# Cells_AreaShape_Center_X                                 0.015926
# Cells_AreaShape_Center_Y                                -0.065376
# Cells_AreaShape_MajorAxisLength                         -0.105150
# Cells_AreaShape_MaxFeretDiameter                        -0.109530
# ...                                                           ...
# Nuclei_Texture_Variance_Mito_3_0                         0.343709
# Nuclei_Texture_Variance_Mito_5_0                         0.340259
# Nuclei_Texture_Variance_RNA_10_0                         0.924238
# Nuclei_Texture_Variance_RNA_3_0                          0.987692
# Nuclei_Texture_Variance_RNA_5_0                          1.000000
#
# [674 rows x 674 columns]

# %%
pairwise_df
# Out:
#                                  pair_a                             pair_b  \
# 0              Cells_AreaShape_Center_X               Cells_AreaShape_Area
# 1              Cells_AreaShape_Center_Y               Cells_AreaShape_Area
# 2              Cells_AreaShape_Center_Y           Cells_AreaShape_Center_X
# 3       Cells_AreaShape_MajorAxisLength               Cells_AreaShape_Area
# 4       Cells_AreaShape_MajorAxisLength           Cells_AreaShape_Center_X
# ...                                 ...                                ...
# 226796  Nuclei_Texture_Variance_RNA_5_0  Nuclei_Texture_Variance_Mito_10_0
# 226797  Nuclei_Texture_Variance_RNA_5_0   Nuclei_Texture_Variance_Mito_3_0
# 226798  Nuclei_Texture_Variance_RNA_5_0   Nuclei_Texture_Variance_Mito_5_0
# 226799  Nuclei_Texture_Variance_RNA_5_0   Nuclei_Texture_Variance_RNA_10_0
# 226800  Nuclei_Texture_Variance_RNA_5_0    Nuclei_Texture_Variance_RNA_3_0
#
#         correlation
# 0         -0.043368
# 1          0.008753
# 2         -0.003357
# 3          0.956153
# 4         -0.039532
# ...             ...
# 226796     0.294346
# 226797     0.343709
# 226798     0.340259
# 226799     0.924238
# 226800     0.987692
#
# [226801 rows x 3 columns]

# %%
def determine_high_cor_pair(correlation_row, sorted_correlation_pairs):
    """
    Select highest correlated variable given a correlation row with columns:
    ["pair_a", "pair_b", "correlation"]
    For use in a pandas.apply()
    """

    pair_a = correlation_row["pair_a"]
    pair_b = correlation_row["pair_b"]

    if sorted_correlation_pairs.get_loc(pair_a) > sorted_correlation_pairs.get_loc(pair_b):
        return pair_a
    else:
        return pair_b

# %%
# Get absolute sum of correlation across features
# The lower the index, the less correlation to the full data frame
# We want to drop features with highest correlation, so drop higher index
variable_cor_sum = data_cor_df.abs().sum().sort_values().index

# And subset to only variable combinations that pass the threshold
pairwise_df = pairwise_df.query("correlation > 0.9")

# Return an empty list if nothing is over correlation threshold
print(pairwise_df.shape[0])
      
excluded = pairwise_df.apply(lambda x: determine_high_cor_pair(x, variable_cor_sum), axis="columns")
excluded_features = list(set(excluded.tolist()))
# Out:
# 2247

# %%
len(excluded_features)
# Out:
# 426

# %%
new_CP_broad_data_2 = new_CP_broad_data.drop(excluded_features, axis=1)
new_CP_broad_data_2
# Out:
#        Cells_AreaShape_Orientation  Cells_AreaShape_Perimeter  \
# 0                        -5.134609                 -61.097194
# 1                        -2.492982                   4.570500
# 2                         0.106234                 207.720969
# 3                         1.706835                 -16.486734
# 4                         1.863808                  -4.849000
# ...                            ...                        ...
# 15267                    -6.264879                -181.273562
# 15268                     0.687631                 290.694656
# 15269                   -10.259331                 -32.490180
# 15270                     2.494232                  27.485375
# 15271                     0.831877                  50.622375
#
#        Cells_Correlation_Correlation_RNA_AGP  \
# 0                                   0.213520
# 1                                   0.500980
# 2                                   0.554610
# 3                                   0.065095
# 4                                   0.116754
# ...                                      ...
# 15267                               0.600421
# 15268                               0.357634
# 15269                               0.385746
# 15270                               0.078460
# 15271                               0.088166
#
#        Cells_Correlation_Costes_AGP_RNA  Cells_Correlation_K_AGP_DNA  \
# 0                              0.052182                     0.340759
# 1                             -0.049488                     0.034006
# 2                             -0.037230                    -0.144126
# 3                              0.052121                    -0.021547
# 4                             -0.089409                    -0.006915
# ...                                 ...                          ...
# 15267                          0.006980                     0.341992
# 15268                         -0.102040                    -0.155204
# 15269                         -0.010448                     0.021540
# 15270                          0.015044                    -0.009505
# 15271                          0.013988                    -0.038157
#
#        Cells_Correlation_K_DNA_AGP  Cells_Correlation_K_DNA_ER  \
# 0                        -0.107108                    0.030104
# 1                         0.009368                    0.042325
# 2                         0.907236                    0.762857
# 3                         0.185901                    0.081906
# 4                        -0.116876                   -0.017143
# ...                            ...                         ...
# 15267                    -0.482678                   -0.421343
# 15268                     1.278826                    0.829811
# 15269                    -0.015133                   -0.165300
# 15270                    -0.009737                   -0.060708
# 15271                     0.098509                    0.186182
#
#        Cells_Correlation_K_DNA_Mito  Cells_Correlation_K_ER_DNA  \
# 0                          0.043808                   -0.058823
# 1                          0.289250                    0.072184
# 2                          0.869041                   -0.197808
# 3                          0.034104                   -0.030566
# 4                          0.037999                    0.008466
# ...                             ...                         ...
# 15267                      0.160259                    0.486249
# 15268                      0.756359                   -0.187745
# 15269                      0.102597                    0.144109
# 15270                     -0.000053                   -0.001857
# 15271                      0.156374                   -0.133162
#
#        Cells_Correlation_K_ER_Mito  ...  Nuclei_Texture_SumAverage_RNA_10_0  \
# 0                        -0.076555  ...                            0.252428
# 1                         0.236915  ...                            0.056020
# 2                         0.050745  ...                            0.750304
# 3                        -0.068275  ...                            0.265664
# 4                         0.130419  ...                            0.028058
# ...                            ...  ...                                 ...
# 15267                     0.404443  ...                            1.100196
# 15268                    -0.028950  ...                           -0.655888
# 15269                     0.218774  ...                            0.832114
# 15270                     0.068244  ...                            0.273783
# 15271                    -0.023434  ...                            0.312031
#
#        Nuclei_Texture_SumVariance_AGP_10_0  \
# 0                                 0.127041
# 1                                 0.113111
# 2                                 0.402068
# 3                                -0.356829
# 4                                -0.565546
# ...                                    ...
# 15267                             0.854714
# 15268                            -0.235418
# 15269                             0.822444
# 15270                            -0.252019
# 15271                            -0.036430
#
#        Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                                 0.300797
# 1                                -0.031291
# 2                                -0.528586
# 3                                -0.001533
# 4                                -0.050469
# ...                                    ...
# 15267                             0.141265
# 15268                            -1.117448
# 15269                             0.501358
# 15270                             0.261459
# 15271                            -0.078891
#
#        Nuclei_Texture_SumVariance_ER_10_0  \
# 0                                1.601798
# 1                                0.736375
# 2                                0.894280
# 3                                0.040114
# 4                               -0.191591
# ...                                   ...
# 15267                            1.257099
# 15268                           -0.116413
# 15269                            0.956281
# 15270                           -0.101648
# 15271                           -0.205359
#
#        Nuclei_Texture_SumVariance_Mito_10_0  \
# 0                                  0.649545
# 1                                 -0.052299
# 2                                  1.096441
# 3                                 -0.145918
# 4                                 -0.484524
# ...                                     ...
# 15267                              0.942200
# 15268                              0.036485
# 15269                              1.116960
# 15270                             -0.197162
# 15271                             -0.157530
#
#        Nuclei_Texture_SumVariance_RNA_10_0  Nuclei_Texture_Variance_AGP_10_0  \
# 0                                 0.117986                         -0.124655
# 1                                -0.182771                          0.020039
# 2                                 0.201130                          0.023909
# 3                                 0.025249                         -0.111571
# 4                                -0.230474                         -0.250742
# ...                                    ...                               ...
# 15267                             0.412648                          1.143416
# 15268                             0.631407                         -0.277122
# 15269                             0.726610                          0.275630
# 15270                            -0.011630                         -0.169541
# 15271                            -0.114362                         -0.047605
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                             0.875722                           0.060316
# 1                             0.309519                           0.146067
# 2                             0.209528                           0.384470
# 3                             0.086286                          -0.083360
# 4                            -0.028181                          -0.188926
# ...                                ...                                ...
# 15267                         1.082932                           0.892884
# 15268                        -0.071896                          -0.108458
# 15269                         0.493553                           0.230773
# 15270                        -0.096224                          -0.132107
# 15271                        -0.037492                          -0.033800
#
#        Nuclei_Texture_Variance_RNA_10_0
# 0                             -0.108497
# 1                             -0.135633
# 2                              0.242193
# 3                              0.011623
# 4                             -0.048785
# ...                                 ...
# 15267                          1.190745
# 15268                          0.260039
# 15269                          0.175383
# 15270                          0.046411
# 15271                         -0.120534
#
# [15272 rows x 248 columns]

# %%
max_feature_values = new_CP_broad_data_2.max().abs()
min_feature_values = new_CP_broad_data_2.min().abs()

outlier_features = max_feature_values[(max_feature_values > 15) | (min_feature_values > 15)].index.tolist()

# %%
new_CP_broad_data_3 = new_CP_broad_data_2.drop(outlier_features, axis=1)
new_CP_broad_data_3
# Out:
#        Cells_Correlation_Correlation_RNA_AGP  \
# 0                                   0.213520
# 1                                   0.500980
# 2                                   0.554610
# 3                                   0.065095
# 4                                   0.116754
# ...                                      ...
# 15267                               0.600421
# 15268                               0.357634
# 15269                               0.385746
# 15270                               0.078460
# 15271                               0.088166
#
#        Cells_Correlation_Costes_AGP_RNA  Cells_Correlation_K_AGP_DNA  \
# 0                              0.052182                     0.340759
# 1                             -0.049488                     0.034006
# 2                             -0.037230                    -0.144126
# 3                              0.052121                    -0.021547
# 4                             -0.089409                    -0.006915
# ...                                 ...                          ...
# 15267                          0.006980                     0.341992
# 15268                         -0.102040                    -0.155204
# 15269                         -0.010448                     0.021540
# 15270                          0.015044                    -0.009505
# 15271                          0.013988                    -0.038157
#
#        Cells_Correlation_K_DNA_AGP  Cells_Correlation_K_DNA_ER  \
# 0                        -0.107108                    0.030104
# 1                         0.009368                    0.042325
# 2                         0.907236                    0.762857
# 3                         0.185901                    0.081906
# 4                        -0.116876                   -0.017143
# ...                            ...                         ...
# 15267                    -0.482678                   -0.421343
# 15268                     1.278826                    0.829811
# 15269                    -0.015133                   -0.165300
# 15270                    -0.009737                   -0.060708
# 15271                     0.098509                    0.186182
#
#        Cells_Correlation_K_DNA_Mito  Cells_Correlation_K_ER_DNA  \
# 0                          0.043808                   -0.058823
# 1                          0.289250                    0.072184
# 2                          0.869041                   -0.197808
# 3                          0.034104                   -0.030566
# 4                          0.037999                    0.008466
# ...                             ...                         ...
# 15267                      0.160259                    0.486249
# 15268                      0.756359                   -0.187745
# 15269                      0.102597                    0.144109
# 15270                     -0.000053                   -0.001857
# 15271                      0.156374                   -0.133162
#
#        Cells_Correlation_K_ER_Mito  Cells_Correlation_K_Mito_DNA  \
# 0                        -0.076555                     -0.080047
# 1                         0.236915                     -0.090521
# 2                         0.050745                     -0.265411
# 3                        -0.068275                     -0.000007
# 4                         0.130419                     -0.026270
# ...                            ...                           ...
# 15267                     0.404443                      0.035852
# 15268                    -0.028950                     -0.237447
# 15269                     0.218774                     -0.041078
# 15270                     0.068244                     -0.021163
# 15271                    -0.023434                     -0.117217
#
#        Cells_Correlation_K_RNA_DNA  ...  Nuclei_Texture_SumAverage_RNA_10_0  \
# 0                        -0.060985  ...                            0.252428
# 1                         0.025497  ...                            0.056020
# 2                        -0.223704  ...                            0.750304
# 3                        -0.060455  ...                            0.265664
# 4                         0.015191  ...                            0.028058
# ...                            ...  ...                                 ...
# 15267                     0.378471  ...                            1.100196
# 15268                    -0.202268  ...                           -0.655888
# 15269                     0.056075  ...                            0.832114
# 15270                     0.063623  ...                            0.273783
# 15271                    -0.128264  ...                            0.312031
#
#        Nuclei_Texture_SumVariance_AGP_10_0  \
# 0                                 0.127041
# 1                                 0.113111
# 2                                 0.402068
# 3                                -0.356829
# 4                                -0.565546
# ...                                    ...
# 15267                             0.854714
# 15268                            -0.235418
# 15269                             0.822444
# 15270                            -0.252019
# 15271                            -0.036430
#
#        Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                                 0.300797
# 1                                -0.031291
# 2                                -0.528586
# 3                                -0.001533
# 4                                -0.050469
# ...                                    ...
# 15267                             0.141265
# 15268                            -1.117448
# 15269                             0.501358
# 15270                             0.261459
# 15271                            -0.078891
#
#        Nuclei_Texture_SumVariance_ER_10_0  \
# 0                                1.601798
# 1                                0.736375
# 2                                0.894280
# 3                                0.040114
# 4                               -0.191591
# ...                                   ...
# 15267                            1.257099
# 15268                           -0.116413
# 15269                            0.956281
# 15270                           -0.101648
# 15271                           -0.205359
#
#        Nuclei_Texture_SumVariance_Mito_10_0  \
# 0                                  0.649545
# 1                                 -0.052299
# 2                                  1.096441
# 3                                 -0.145918
# 4                                 -0.484524
# ...                                     ...
# 15267                              0.942200
# 15268                              0.036485
# 15269                              1.116960
# 15270                             -0.197162
# 15271                             -0.157530
#
#        Nuclei_Texture_SumVariance_RNA_10_0  Nuclei_Texture_Variance_AGP_10_0  \
# 0                                 0.117986                         -0.124655
# 1                                -0.182771                          0.020039
# 2                                 0.201130                          0.023909
# 3                                 0.025249                         -0.111571
# 4                                -0.230474                         -0.250742
# ...                                    ...                               ...
# 15267                             0.412648                          1.143416
# 15268                             0.631407                         -0.277122
# 15269                             0.726610                          0.275630
# 15270                            -0.011630                         -0.169541
# 15271                            -0.114362                         -0.047605
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                             0.875722                           0.060316
# 1                             0.309519                           0.146067
# 2                             0.209528                           0.384470
# 3                             0.086286                          -0.083360
# 4                            -0.028181                          -0.188926
# ...                                ...                                ...
# 15267                         1.082932                           0.892884
# 15268                        -0.071896                          -0.108458
# 15269                         0.493553                           0.230773
# 15270                        -0.096224                          -0.132107
# 15271                        -0.037492                          -0.033800
#
#        Nuclei_Texture_Variance_RNA_10_0
# 0                             -0.108497
# 1                             -0.135633
# 2                              0.242193
# 3                              0.011623
# 4                             -0.048785
# ...                                 ...
# 15267                          1.190745
# 15268                          0.260039
# 15269                          0.175383
# 15270                          0.046411
# 15271                         -0.120534
#
# [15272 rows x 191 columns]

# %%
new_CP_broad_data_3["InChICode_standardised"]= CP_broad_data["InChICode_standardised"]
new_CP_broad_data_3
# Out:
#        Cells_Correlation_Correlation_RNA_AGP  \
# 0                                   0.213520
# 1                                   0.500980
# 2                                   0.554610
# 3                                   0.065095
# 4                                   0.116754
# ...                                      ...
# 15267                               0.600421
# 15268                               0.357634
# 15269                               0.385746
# 15270                               0.078460
# 15271                               0.088166
#
#        Cells_Correlation_Costes_AGP_RNA  Cells_Correlation_K_AGP_DNA  \
# 0                              0.052182                     0.340759
# 1                             -0.049488                     0.034006
# 2                             -0.037230                    -0.144126
# 3                              0.052121                    -0.021547
# 4                             -0.089409                    -0.006915
# ...                                 ...                          ...
# 15267                          0.006980                     0.341992
# 15268                         -0.102040                    -0.155204
# 15269                         -0.010448                     0.021540
# 15270                          0.015044                    -0.009505
# 15271                          0.013988                    -0.038157
#
#        Cells_Correlation_K_DNA_AGP  Cells_Correlation_K_DNA_ER  \
# 0                        -0.107108                    0.030104
# 1                         0.009368                    0.042325
# 2                         0.907236                    0.762857
# 3                         0.185901                    0.081906
# 4                        -0.116876                   -0.017143
# ...                            ...                         ...
# 15267                    -0.482678                   -0.421343
# 15268                     1.278826                    0.829811
# 15269                    -0.015133                   -0.165300
# 15270                    -0.009737                   -0.060708
# 15271                     0.098509                    0.186182
#
#        Cells_Correlation_K_DNA_Mito  Cells_Correlation_K_ER_DNA  \
# 0                          0.043808                   -0.058823
# 1                          0.289250                    0.072184
# 2                          0.869041                   -0.197808
# 3                          0.034104                   -0.030566
# 4                          0.037999                    0.008466
# ...                             ...                         ...
# 15267                      0.160259                    0.486249
# 15268                      0.756359                   -0.187745
# 15269                      0.102597                    0.144109
# 15270                     -0.000053                   -0.001857
# 15271                      0.156374                   -0.133162
#
#        Cells_Correlation_K_ER_Mito  Cells_Correlation_K_Mito_DNA  \
# 0                        -0.076555                     -0.080047
# 1                         0.236915                     -0.090521
# 2                         0.050745                     -0.265411
# 3                        -0.068275                     -0.000007
# 4                         0.130419                     -0.026270
# ...                            ...                           ...
# 15267                     0.404443                      0.035852
# 15268                    -0.028950                     -0.237447
# 15269                     0.218774                     -0.041078
# 15270                     0.068244                     -0.021163
# 15271                    -0.023434                     -0.117217
#
#        Cells_Correlation_K_RNA_DNA  ...  Nuclei_Texture_SumVariance_AGP_10_0  \
# 0                        -0.060985  ...                             0.127041
# 1                         0.025497  ...                             0.113111
# 2                        -0.223704  ...                             0.402068
# 3                        -0.060455  ...                            -0.356829
# 4                         0.015191  ...                            -0.565546
# ...                            ...  ...                                  ...
# 15267                     0.378471  ...                             0.854714
# 15268                    -0.202268  ...                            -0.235418
# 15269                     0.056075  ...                             0.822444
# 15270                     0.063623  ...                            -0.252019
# 15271                    -0.128264  ...                            -0.036430
#
#        Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                                 0.300797
# 1                                -0.031291
# 2                                -0.528586
# 3                                -0.001533
# 4                                -0.050469
# ...                                    ...
# 15267                             0.141265
# 15268                            -1.117448
# 15269                             0.501358
# 15270                             0.261459
# 15271                            -0.078891
#
#        Nuclei_Texture_SumVariance_ER_10_0  \
# 0                                1.601798
# 1                                0.736375
# 2                                0.894280
# 3                                0.040114
# 4                               -0.191591
# ...                                   ...
# 15267                            1.257099
# 15268                           -0.116413
# 15269                            0.956281
# 15270                           -0.101648
# 15271                           -0.205359
#
#        Nuclei_Texture_SumVariance_Mito_10_0  \
# 0                                  0.649545
# 1                                 -0.052299
# 2                                  1.096441
# 3                                 -0.145918
# 4                                 -0.484524
# ...                                     ...
# 15267                              0.942200
# 15268                              0.036485
# 15269                              1.116960
# 15270                             -0.197162
# 15271                             -0.157530
#
#        Nuclei_Texture_SumVariance_RNA_10_0  Nuclei_Texture_Variance_AGP_10_0  \
# 0                                 0.117986                         -0.124655
# 1                                -0.182771                          0.020039
# 2                                 0.201130                          0.023909
# 3                                 0.025249                         -0.111571
# 4                                -0.230474                         -0.250742
# ...                                    ...                               ...
# 15267                             0.412648                          1.143416
# 15268                             0.631407                         -0.277122
# 15269                             0.726610                          0.275630
# 15270                            -0.011630                         -0.169541
# 15271                            -0.114362                         -0.047605
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                             0.875722                           0.060316
# 1                             0.309519                           0.146067
# 2                             0.209528                           0.384470
# 3                             0.086286                          -0.083360
# 4                            -0.028181                          -0.188926
# ...                                ...                                ...
# 15267                         1.082932                           0.892884
# 15268                        -0.071896                          -0.108458
# 15269                         0.493553                           0.230773
# 15270                        -0.096224                          -0.132107
# 15271                        -0.037492                          -0.033800
#
#        Nuclei_Texture_Variance_RNA_10_0  \
# 0                             -0.108497
# 1                             -0.135633
# 2                              0.242193
# 3                              0.011623
# 4                             -0.048785
# ...                                 ...
# 15267                          1.190745
# 15268                          0.260039
# 15269                          0.175383
# 15270                          0.046411
# 15271                         -0.120534
#
#                                   InChICode_standardised
# 0      InChI=1S/C20H29NO5S/c1-13-5-3-4-6-14(2)9-18(22...
# 1      InChI=1S/C22H26N2O3/c1-25-20-9-5-18(6-10-20)4-...
# 2      InChI=1S/C10H12ClN5O3/c11-10-14-8(12)7-9(15-10...
# 3      InChI=1S/C31H39F3N4O5/c1-19-16-38(20(2)18-39)2...
# 4      InChI=1S/C36H40N4O4/c1-25-21-40(26(2)24-41)35(...
# ...                                                  ...
# 15267  InChI=1S/C29H42O10/c1-15-22(32)23(33)24(34)25(...
# 15268  InChI=1S/C9H11N3O4/c10-5-1-2-12-8-7(16-9(12)11...
# 15269  InChI=1S/C22H22O8/c1-25-14-5-10(6-15(26-2)20(1...
# 15270  InChI=1S/C40H71NO14/c1-15-27-40(11,48)33(44)22...
# 15271  InChI=1S/C25H34N2O3/c1-5-26(6-2)13-15-29-19-9-...
#
# [15272 rows x 192 columns]

# %%
new_CP_broad_data_3.to_csv("CP_filtered_15272.csv", index=False)
new_CP_broad_data_3
# Out:
#        Cells_Correlation_Correlation_RNA_AGP  \
# 0                                   0.213520
# 1                                   0.500980
# 2                                   0.554610
# 3                                   0.065095
# 4                                   0.116754
# ...                                      ...
# 15267                               0.600421
# 15268                               0.357634
# 15269                               0.385746
# 15270                               0.078460
# 15271                               0.088166
#
#        Cells_Correlation_Costes_AGP_RNA  Cells_Correlation_K_AGP_DNA  \
# 0                              0.052182                     0.340759
# 1                             -0.049488                     0.034006
# 2                             -0.037230                    -0.144126
# 3                              0.052121                    -0.021547
# 4                             -0.089409                    -0.006915
# ...                                 ...                          ...
# 15267                          0.006980                     0.341992
# 15268                         -0.102040                    -0.155204
# 15269                         -0.010448                     0.021540
# 15270                          0.015044                    -0.009505
# 15271                          0.013988                    -0.038157
#
#        Cells_Correlation_K_DNA_AGP  Cells_Correlation_K_DNA_ER  \
# 0                        -0.107108                    0.030104
# 1                         0.009368                    0.042325
# 2                         0.907236                    0.762857
# 3                         0.185901                    0.081906
# 4                        -0.116876                   -0.017143
# ...                            ...                         ...
# 15267                    -0.482678                   -0.421343
# 15268                     1.278826                    0.829811
# 15269                    -0.015133                   -0.165300
# 15270                    -0.009737                   -0.060708
# 15271                     0.098509                    0.186182
#
#        Cells_Correlation_K_DNA_Mito  Cells_Correlation_K_ER_DNA  \
# 0                          0.043808                   -0.058823
# 1                          0.289250                    0.072184
# 2                          0.869041                   -0.197808
# 3                          0.034104                   -0.030566
# 4                          0.037999                    0.008466
# ...                             ...                         ...
# 15267                      0.160259                    0.486249
# 15268                      0.756359                   -0.187745
# 15269                      0.102597                    0.144109
# 15270                     -0.000053                   -0.001857
# 15271                      0.156374                   -0.133162
#
#        Cells_Correlation_K_ER_Mito  Cells_Correlation_K_Mito_DNA  \
# 0                        -0.076555                     -0.080047
# 1                         0.236915                     -0.090521
# 2                         0.050745                     -0.265411
# 3                        -0.068275                     -0.000007
# 4                         0.130419                     -0.026270
# ...                            ...                           ...
# 15267                     0.404443                      0.035852
# 15268                    -0.028950                     -0.237447
# 15269                     0.218774                     -0.041078
# 15270                     0.068244                     -0.021163
# 15271                    -0.023434                     -0.117217
#
#        Cells_Correlation_K_RNA_DNA  ...  Nuclei_Texture_SumVariance_AGP_10_0  \
# 0                        -0.060985  ...                             0.127041
# 1                         0.025497  ...                             0.113111
# 2                        -0.223704  ...                             0.402068
# 3                        -0.060455  ...                            -0.356829
# 4                         0.015191  ...                            -0.565546
# ...                            ...  ...                                  ...
# 15267                     0.378471  ...                             0.854714
# 15268                    -0.202268  ...                            -0.235418
# 15269                     0.056075  ...                             0.822444
# 15270                     0.063623  ...                            -0.252019
# 15271                    -0.128264  ...                            -0.036430
#
#        Nuclei_Texture_SumVariance_DNA_10_0  \
# 0                                 0.300797
# 1                                -0.031291
# 2                                -0.528586
# 3                                -0.001533
# 4                                -0.050469
# ...                                    ...
# 15267                             0.141265
# 15268                            -1.117448
# 15269                             0.501358
# 15270                             0.261459
# 15271                            -0.078891
#
#        Nuclei_Texture_SumVariance_ER_10_0  \
# 0                                1.601798
# 1                                0.736375
# 2                                0.894280
# 3                                0.040114
# 4                               -0.191591
# ...                                   ...
# 15267                            1.257099
# 15268                           -0.116413
# 15269                            0.956281
# 15270                           -0.101648
# 15271                           -0.205359
#
#        Nuclei_Texture_SumVariance_Mito_10_0  \
# 0                                  0.649545
# 1                                 -0.052299
# 2                                  1.096441
# 3                                 -0.145918
# 4                                 -0.484524
# ...                                     ...
# 15267                              0.942200
# 15268                              0.036485
# 15269                              1.116960
# 15270                             -0.197162
# 15271                             -0.157530
#
#        Nuclei_Texture_SumVariance_RNA_10_0  Nuclei_Texture_Variance_AGP_10_0  \
# 0                                 0.117986                         -0.124655
# 1                                -0.182771                          0.020039
# 2                                 0.201130                          0.023909
# 3                                 0.025249                         -0.111571
# 4                                -0.230474                         -0.250742
# ...                                    ...                               ...
# 15267                             0.412648                          1.143416
# 15268                             0.631407                         -0.277122
# 15269                             0.726610                          0.275630
# 15270                            -0.011630                         -0.169541
# 15271                            -0.114362                         -0.047605
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                             0.875722                           0.060316
# 1                             0.309519                           0.146067
# 2                             0.209528                           0.384470
# 3                             0.086286                          -0.083360
# 4                            -0.028181                          -0.188926
# ...                                ...                                ...
# 15267                         1.082932                           0.892884
# 15268                        -0.071896                          -0.108458
# 15269                         0.493553                           0.230773
# 15270                        -0.096224                          -0.132107
# 15271                        -0.037492                          -0.033800
#
#        Nuclei_Texture_Variance_RNA_10_0  \
# 0                             -0.108497
# 1                             -0.135633
# 2                              0.242193
# 3                              0.011623
# 4                             -0.048785
# ...                                 ...
# 15267                          1.190745
# 15268                          0.260039
# 15269                          0.175383
# 15270                          0.046411
# 15271                         -0.120534
#
#                                   InChICode_standardised
# 0      InChI=1S/C20H29NO5S/c1-13-5-3-4-6-14(2)9-18(22...
# 1      InChI=1S/C22H26N2O3/c1-25-20-9-5-18(6-10-20)4-...
# 2      InChI=1S/C10H12ClN5O3/c11-10-14-8(12)7-9(15-10...
# 3      InChI=1S/C31H39F3N4O5/c1-19-16-38(20(2)18-39)2...
# 4      InChI=1S/C36H40N4O4/c1-25-21-40(26(2)24-41)35(...
# ...                                                  ...
# 15267  InChI=1S/C29H42O10/c1-15-22(32)23(33)24(34)25(...
# 15268  InChI=1S/C9H11N3O4/c10-5-1-2-12-8-7(16-9(12)11...
# 15269  InChI=1S/C22H22O8/c1-25-14-5-10(6-15(26-2)20(1...
# 15270  InChI=1S/C40H71NO14/c1-15-27-40(11,48)33(44)22...
# 15271  InChI=1S/C25H34N2O3/c1-5-26(6-2)13-15-29-19-9-...
#
# [15272 rows x 192 columns]
